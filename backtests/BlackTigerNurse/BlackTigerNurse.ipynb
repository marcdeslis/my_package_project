# %% [markdown]
# ## <center> Backtest Results Notebook </center>

# %% [markdown]
# Backtest Name: BlackTigerNurse

# %% [markdown]
# Backtest Period: 2017-01-01 to 2020-12-31

# %% [markdown]
# ### Stocks Used in Backtest:
# - SPY
# - TLT
# - GLD

# %% [markdown]
# Initial Portfolio Weights

# %%
from IPython.display import Image
Image(filename='initial_weights.png')

# %% [markdown]
# Risk Contributions Pie Chart

# %%
Image(filename='risk_allocation_pie.png')

# %% [markdown]
# Portfolio Weights Over Time

# %%
Image(filename='weights_over_time.png')

# %% [markdown]
# - **Annualized Volatility**: 9.64%
# - **Annualized Return**: 11.08%
# - **Sharpe Ratio**: 0.94

# %% [markdown]
# Portfolio Value Over Time

# %%
Image(filename='portfolio_value_over_time.png')

# %% [markdown]
# Transaction Log

# %%
import pandas as pd
df = pd.read_csv('transaction_log.csv').drop(columns=['Unnamed: 0'])
df.head()
# Out:
#          Date Action Ticker  Quantity       Price           Cash
# 0  2017-01-31    BUY    GLD      1423  113.970001  837820.688263
# 1  2017-01-31    BUY    SPY      2024  199.312225  434412.744171
# 2  2017-01-31    BUY    TLT      4458   97.378296     300.301056
# 3  2017-02-28   SELL    SPY      1323  207.685852  275068.683319
# 4  2017-02-28    BUY    GLD       127  119.120003  259940.442970
